# %% [markdown]
# <a href="https://colab.research.google.com/github/utensil/julia-playground/blob/master/hello-sym.jl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installation cell
# %%capture
%%shell
if ! command -v julia 3>&1 > /dev/null
then
    wget -q 'https://julialang-s3.julialang.org/bin/linux/x64/1.9/julia-1.9.0-linux-x86_64.tar.gz' \
        -O /tmp/julia.tar.gz
    tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
    rm /tmp/julia.tar.gz
fi
julia -e 'using Pkg; pkg"add IJulia; precompile;"'
echo 'Done'
# Out:
# ┌ Warning: The Pkg REPL mode is intended for interactive use only, and should not be used from scripts. It is recommended to use the functional API instead.
# └ @ Pkg.REPLMode /usr/local/share/julia/stdlib/v1.9/Pkg/src/REPLMode/REPLMode.jl:382
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Conda ─────────── v1.8.0
#    Installed ZMQ ───────────── v1.2.2
#    Installed Parsers ───────── v2.5.10
#    Installed Preferences ───── v1.4.0
#    Installed IJulia ────────── v1.24.0
#    Installed JSON ──────────── v0.21.4
#    Installed JLLWrappers ───── v1.4.1
#    Installed PrecompileTools ─ v1.1.1
#    Installed ZeroMQ_jll ────── v4.3.4+0
#    Installed VersionParsing ── v1.3.0
#    Installed SoftGlobalScope ─ v1.1.0
#    Installed libsodium_jll ─── v1.0.20+0
#    Installed MbedTLS ───────── v1.1.7
# ...
#   Downloaded artifact: ZeroMQ
# ...
#   Downloaded artifact: libsodium
# ...

# %% [markdown]
# Next, go to **Edit** -> **Notebook settings**, ensure the runtime is Julia, Click **Save**, the runtime will reconnect, then execute the following:

# %%
VERSION
# Out:
# v"1.9.0"

# %%
;jupyter kernelspec list
# Out:
# Available kernels:
#   julia-1.9    /root/.local/share/jupyter/kernels/julia-1.9
#   ir           /usr/local/share/jupyter/kernels/ir
#   python3      /usr/local/share/jupyter/kernels/python3

# %%
using Pkg
Pkg.add("Symbolics")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed DiffRules ─────────────────── v1.13.0
#    Installed GPUArraysCore ─────────────── v0.1.4
#    Installed Tricks ────────────────────── v0.1.7
#    Installed Calculus ──────────────────── v0.5.1
#    Installed DynamicPolynomials ────────── v0.4.6
#    Installed RandomExtensions ──────────── v0.4.3
#    Installed FunctionWrappersWrappers ──── v0.1.3
#    Installed MutableArithmetics ────────── v1.3.0
#    Installed TreeViews ─────────────────── v0.3.0
#    Installed Rmath ─────────────────────── v0.7.1
#    Installed DualNumbers ───────────────── v0.6.8
#    Installed MultivariatePolynomials ───── v0.4.7
#    Installed IntegerMathUtils ──────────── v0.1.0
#    Installed HypergeometricFunctions ───── v0.3.16
#    Installed IntervalSets ──────────────── v0.7.4
#    Installed CompositeTypes ────────────── v0.1.3
#    Installed TableTraits ───────────────── v1.0.1
# ...

# %%
Pkg.add("SymbolicUtils")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.9/Project.toml`
#   [d1185830] + SymbolicUtils v1.0.5
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
using SymbolicUtils

# %%
@syms x::Real y::Real z::Complex f(::Number)::Real
# Out:
# (x, y, z, f)

# %%
2x^2 - y + x^2
# Out:
# 3(x^2) - y

# %%
f(sin(x)^2 + cos(x)^2) + z
# Out:
# z + f(cos(x)^2 + sin(x)^2)

# %%
using Symbolics
@variables x y
# Out:
# 2-element Vector{Num}:
#  x
#  y
